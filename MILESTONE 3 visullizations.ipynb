# %%
#IMPORTING THE LIBRARIES
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# Load the dataset
data=pd.read_csv('NSE-Tata-Global-Beverages-Limited.CSV')
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  08/10/2018  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  05/10/2018  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  04/10/2018  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  03/10/2018  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  01/10/2018  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs) stock_price_change_in _percentage     trend
# 0         10062.83                            3.4375  positive
# 1          7407.06                      -3.594470046  negative
# 2          3815.79                      -2.371364653  negative
# 3          3960.27                      -1.043478261  negative
# 4         10062.83                      -1.556171392  negative

# %%
data.isnull().sum()
# Out:
# Date                                  0
# Open                                 12
# High                                  5
# Low                                   1
# Last                                  3
# Close                                 1
# Total Trade Quantity                  2
# Turnover (Lacs)                       2
# stock_price_change_in _percentage     0
# trend                                 0
# dtype: int64

# %%
data.rename( columns={'Turnover (Lacs)':'Turnover'} ,inplace=True)

# %%
data
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     08/10/2018  208.00  222.25  206.85  216.00  215.15
# 1     05/10/2018  217.00  218.60  205.90  210.25  209.20
# 2     04/10/2018  223.50  227.80  216.15  217.25  218.20
# 3     03/10/2018  230.00  237.50  225.75  226.45  227.60
# 4     01/10/2018  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  14/10/2013  160.85  161.45  157.70  159.30  159.45
# 1231  11/10/2013  161.15  163.45  159.00  159.80  160.05
# 1232  10/10/2013  156.00  160.80  155.85  160.30  160.15
# 1233  09/10/2013  155.70  158.20  154.15  155.30  155.55
# 1234  08/10/2013  157.00  157.80  155.20  155.80  155.80
#
#       Total Trade Quantity  Turnover stock_price_change_in _percentage  \
# 0                4642146.0  10062.83                            3.4375
# 1                3519515.0   7407.06                      -3.594470046
# ...

# %%
# fillna()---handle the missing values (option-1)
mean_Close=data['Close'].mean()
data['Close'].fillna(mean_Close, inplace=True)
mean_Close=data['Close'].mean()
data['Close'].fillna(mean_Close, inplace=True)

# %%
mean_Open=data['Open'].mean()
data['Open'].fillna(mean_Open, inplace=True)
mean_Open=data['Open'].mean()
data['Open'].fillna(mean_Open, inplace=True)

# %%
mean_High=data['High'].mean()
data['High'].fillna(mean_High, inplace=True)
mean_High=data['High'].mean()
data['High'].fillna(mean_High, inplace=True)

# %%
mean_Low=data['Low'].mean()
data['Low'].fillna(mean_High, inplace=True)
mean_High=data['High'].mean()
data['High'].fillna(mean_High, inplace=True)

# %%
mean_Total_Trade_Quantity=data['Total Trade Quantity'].mean()
data['Total Trade Quantity'].fillna(mean_Total_Trade_Quantity, inplace=True)
mean_Total_Trade_Quantity=data['Total Trade Quantity'].mean()
data['Total Trade Quantity'].fillna(mean_Total_Trade_Quantity, inplace=True)

# %%
mean_Turnover=data['Turnover'].mean()
data['Turnover'].fillna(mean_Turnover,inplace=True)
mean_Turnover=data['Turnover'].mean()
data['Turnover'].fillna(mean_Turnover,inplace=True)

# %%
mean_Last=data['Last'].mean()
data['Last'].fillna(mean_Last,inplace=True)
mean_Last=data['Last'].mean()
data['Last'].fillna(mean_Last,inplace=True)

# %%
data.isnull().sum()
# Out:
# Date                                 0
# Open                                 0
# High                                 0
# Low                                  0
# Last                                 0
# Close                                0
# Total Trade Quantity                 0
# Turnover                             0
# stock_price_change_in _percentage    0
# trend                                0
# dtype: int64

# %%
x=data.Date
y=data.Open
plt.plot(x,y)

# %%
x=data.Date
y=data.Close
plt.plot(x,y)

# %%
x=data.Date
y=data.High
plt.plot(x,y)

# %%
x=data.Date
y=data.Low
plt.plot(x,y)

# %%
x=data.Date
y=data.Last
plt.plot(x,y)

# %%
data.columns = data.columns.str.replace(' ','_')

# %%
data
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     08/10/2018  208.00  222.25  206.85  216.00  215.15
# 1     05/10/2018  217.00  218.60  205.90  210.25  209.20
# 2     04/10/2018  223.50  227.80  216.15  217.25  218.20
# 3     03/10/2018  230.00  237.50  225.75  226.45  227.60
# 4     01/10/2018  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  14/10/2013  160.85  161.45  157.70  159.30  159.45
# 1231  11/10/2013  161.15  163.45  159.00  159.80  160.05
# 1232  10/10/2013  156.00  160.80  155.85  160.30  160.15
# 1233  09/10/2013  155.70  158.20  154.15  155.30  155.55
# 1234  08/10/2013  157.00  157.80  155.20  155.80  155.80
#
#       Total_Trade_Quantity  Turnover stock_price_change_in__percentage  \
# 0                4642146.0  10062.83                            3.4375
# 1                3519515.0   7407.06                      -3.594470046
# ...

# %%
x=data.Date
y=data.Total_Trade_Quantity
plt.plot(x,y)

# %%
data.rename( columns={'Turnover_(Lacs)':'Turnover'} ,inplace=True)

# %%
data
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     08/10/2018  208.00  222.25  206.85  216.00  215.15
# 1     05/10/2018  217.00  218.60  205.90  210.25  209.20
# 2     04/10/2018  223.50  227.80  216.15  217.25  218.20
# 3     03/10/2018  230.00  237.50  225.75  226.45  227.60
# 4     01/10/2018  234.55  234.60  221.05  230.30  230.90
# ...          ...     ...     ...     ...     ...     ...
# 1230  14/10/2013  160.85  161.45  157.70  159.30  159.45
# 1231  11/10/2013  161.15  163.45  159.00  159.80  160.05
# 1232  10/10/2013  156.00  160.80  155.85  160.30  160.15
# 1233  09/10/2013  155.70  158.20  154.15  155.30  155.55
# 1234  08/10/2013  157.00  157.80  155.20  155.80  155.80
#
#       Total_Trade_Quantity  Turnover stock_price_change_in__percentage  \
# 0                4642146.0  10062.83                            3.4375
# 1                3519515.0   7407.06                      -3.594470046
# ...

# %%
x=data.Date
y=data.Turnover
plt.plot(x,y)

# %%
x=data.Date
y1=data.Open
y2=data.High
y3=data.Low
y4=data.Last
y5=data.Close
plt.figure(figsize=(18,15))


plt.plot(x,y1, label='Open', color='red')
plt.plot(x,y2, label='Close', color='magenta')
plt.plot(x,y3, label='High', color='blue')
plt.plot(x,y4, label='Low', color='black')
plt.plot(x,y5, label='Last', color='yellow')


plt.legend(loc=6)
plt.xlabel('date')
plt.ylabel('Different prices')
plt.title('comparative prices')
plt.show()

# %%
x=data.Date
y1=data.Open
plt.bar(x, y1, color='magenta')
plt.xlabel('Date')
plt.ylabel('open price')
plt.title('BAr graph of open and date ')
plt.show()

# %%
x=data.Date
y2=data.High
plt.bar(x, y2, color='magenta')
plt.xlabel('Date')
plt.ylabel('high price')
plt.title('BAr graph of high price and date ')
plt.show()

# %%
x=data.Date
y3=data.Low
plt.bar(x, y3, color='magenta')
plt.xlabel('Date')
plt.ylabel('Low price')
plt.title('BAr graph of low price and date ')
plt.show()

# %%
x=data.Date
y4=data.Last
plt.bar(x, y4, color='magenta')
plt.xlabel('Date')
plt.ylabel('last price')
plt.title('BAr graph of last price and date ')
plt.show()

# %%
x=data.Date
y5=data.Close
plt.bar(x, y5, color='magenta')
plt.xlabel('Date')
plt.ylabel('close price')
plt.title('BAr graph of last price and date ')
plt.show()

# %%
x=data.Date
y5=data.Total_Trade_Quantity
plt.bar(x, y5, color='magenta')
plt.xlabel('Date')
plt.ylabel('Total_Trade_Quantity')
plt.title('BAr graph of otal_Trade_Quantity and date ')
plt.show()

# %%
x=data.Date
y6=data.Turnover
plt.bar(x, y6, color='magenta')
plt.xlabel('Date')
plt.ylabel('Turnover')
plt.title('BAr graph of turnover and date ')
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Sactter plot
x_val=data['Date']
y_val=data['Open']
plt.xlabel('Date')
plt.ylabel('Open')
plt.title('Date vs Open')
plt.scatter(x_val,y_val, color='red')

# %%
x_val=data['Date']
y_val=data['Close']
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('Date vs Close')
plt.scatter(x_val,y_val, color='red')

# %%
x_val=data['Date']
y_val=data['High']
plt.xlabel('Date')
plt.ylabel('High')
plt.title('Date vs High')
plt.scatter(x_val,y_val, color='red')

# %%
x_val=data['Date']
y_val=data['Last']
plt.xlabel('Date')
plt.ylabel('Last')
plt.title('Date vs Last')
plt.scatter(x_val,y_val, color='red')

# %%
x_val=data['Date']
y_val=data['Close']
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('Date vs Close')
plt.scatter(x_val,y_val, color='red')

# %%
x_val=data['Date']
y_val=data['Total_Trade_Quantity']
plt.xlabel('Date')
plt.ylabel('Total_Trade_Quantity')
plt.title('Date vs Total_Trade_Quantity')
plt.scatter(x_val,y_val, color='red')

# %%
x_val=data['Date']
y_val=data['Turnover']
plt.xlabel('Date')
plt.ylabel('Turnover')
plt.title('Date vs Turnover')
plt.scatter(x_val,y_val, color='red')

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
x=data.Date
y1=data.Open
y2=data.High
y3=data.Low
y4=data.Last
y5=data.Close
plt.boxplot(y1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29fd08d9940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29fd08e50a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29fd08d95b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29fd08e57c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29fd08e5b50>],
#  'means': []}

# %%
plt.boxplot(y2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29fd0f33160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29fd0f33880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29fd0f23d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x29fd0f33fa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29fd0f3f370>],
#  'means': []}

# %%
plt.boxplot(y3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29fd0f913a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29fd0f91a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29fd0f83fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29fd0f9e1c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29fd0f9e550>],
#  'means': []}

# %%
plt.boxplot(y4)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29fd0feaa30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29fd0ff8190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29fd0fea6a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29fd0ff88b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29fd0ff8c40>],
#  'means': []}

# %%
plt.boxplot(y5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29fd1048df0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29fd1057550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29fd1048a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x29fd1057ca0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29fd1063070>],
#  'means': []}

# %%
y6=data.Total_Trade_Quantity
plt.boxplot(y6)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29fd10b4400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29fd10b4b20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29fd10b4070>],
#  'medians': [<matplotlib.lines.Line2D at 0x29fd10bf280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29fd10bf610>],
#  'means': []}

# %%
y7=data.Turnover
plt.boxplot(y7)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29fd11193a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29fd1119ac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29fd110bfd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29fd1126220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29fd11265b0>],
#  'means': []}

# %%
# categorical plot
sns.catplot(x='Open', y='trend', data=data)

# %%
sns.catplot(x='Close', y='trend', data=data)

# %%
sns.catplot(x='Close', y='trend', data=data)

# %%
sns.catplot(x='Low', y='trend', data=data)

# %% [markdown]
# *Date	Open	High	Low	Last	Close	Total Trade Quantity	Turnover (Lacs)	stock_price_change_in _percentage	trend

# %%
sns.catplot(x='Last', y='trend', data=data)

# %%
sns.catplot(x='Close', y='trend', data=data)

# %%
sns.pairplot(data)

# %%
sns.scatterplot(x='trend',y='Open',data=data)
# Out:
# <AxesSubplot:xlabel='trend', ylabel='Open'>

# %%
sns.scatterplot(x='trend',y='Close',data=data)
# Out:
# <AxesSubplot:xlabel='trend', ylabel='Close'>

# %%
sns.scatterplot(x='trend',y='High',data=data)
# Out:
# <AxesSubplot:xlabel='trend', ylabel='High'>

# %%
# relational plot
sns.relplot(x='Open', y='trend',data=data)

# %%
sns.swarmplot(x='trend', y='Open',data=data)
# Out:
# C:\Users\shaurya khanna\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\shaurya khanna\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='trend', ylabel='Open'>

# %%
sns.swarmplot(x='trend', y='Close',data=data)
# Out:
# C:\Users\shaurya khanna\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 38.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\shaurya khanna\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 51.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='trend', ylabel='Close'>

# %%
sns.swarmplot(x='trend', y='High',data=data)
# Out:
# C:\Users\shaurya khanna\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\shaurya khanna\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 51.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='trend', ylabel='High'>

# %%
# violinplot
sns.violinplot(x='trend', y='Open',data=data)
# Out:
# <AxesSubplot:xlabel='trend', ylabel='Open'>

# %%
sns.violinplot(x='trend', y='Close',data=data)
# Out:
# <AxesSubplot:xlabel='trend', ylabel='Close'>

# %%
sns.violinplot(x='trend', y='High',data=data)
# Out:
# <AxesSubplot:xlabel='trend', ylabel='High'>

# %%
sns.violinplot(x='trend', y='Low',data=data)
# Out:
# <AxesSubplot:xlabel='trend', ylabel='Low'>
